-- %% [markdown]
-- # SQL Part 1 Studio
--
-- ### Let's practice your SQL quering skills!  For each question, work along in the notebook adding your query and answering the questions.
--
-- ### **DataSet**
--
-- ### <span style="font-size: 14px; font-family: -apple-system, BlinkMacSystemFont, sans-serif;">We will be using the Goodbooks-10k dataset from the exercises in the prep work.&nbsp; Feel free to reference your notebook.</span>
--
-- - The dataset can be found here: [goodbooks-10k](https://www.kaggle.com/zygmunt/goodbooks-10k)
-- - You can access the **BooksDB** in the Launchcode server.
--
-- ### **Business Issue**
--
-- You work for a small independant book store and you want to increase sales by running various promotions.  Start by becoming more familar with the BooksDB.

-- %% [markdown]
-- ## Part 1. BooksDB Questions
--
-- <span style="color: rgba(0, 0, 0, 0.87); font-family: -apple-system, system-ui, &quot;Segoe UI&quot;, Helvetica, Arial, sans-serif, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;; background-color: rgb(255, 255, 255);">Question 1:&nbsp; Write a query of the books table, returning the TOP 100 results and&nbsp; includes, book_id, authors, title, average_rating.&nbsp; Use an alias for at least one column and in descending order of rating.&nbsp; What is the number one book?</span>

-- %%
-- return top 100 results
SELECT top 100 book_id, authors, title, average_rating AS 'Best Rated Books' FROM BooksDB.dbo.books 
ORDER BY average_rating DESC;
-- Out:
-- (100 rows affected)
-- Total execution time: 00:00:00.755
-- <table><tr><th>book_id</th><th>authors</th><th>title</th><th>Best Rated Books</th></tr><tr><td>24812</td><td>Bill Watterson</td><td>The Complete Calvin and Hobbes</td><td>4.82</td></tr><tr><td>17332218</td><td>Brandon Sanderson</td><td>Words of Radiance (The Stormlight Archive, #2)</td><td>4.77</td></tr><tr><td>8</td><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5)</td><td>4.77</td></tr><tr><td>5031805</td><td>Anonymous, Lane T. Dennis, Wayne A. Grudem</td><td>ESV Study Bible</td><td>4.76</td></tr><tr><td>95602</td><td>Francine Rivers</td><td>Mark of the Lion Trilogy</td><td>4.76</td></tr><tr><td>24814</td><td>Bill Watterson</td><td>It's a Magical World: A Calvin and Hobbes Collection</td><td>4.75</td></tr><tr><td>862041</td><td>J.K. Rowling</td><td>Harry Potter Boxset (Harry Potter, #1-7)</td><td>4.74</td></tr><tr><td>70489</td><td>Bill Watterson</td><td>There's Treasure Everywhere: A Calvin and Hobbes Collection</td><td>4.74</td></tr><tr><td>10</td><td>J.K. Rowling</td><td>Harry Potter Collection (Harry Potter, #1-6)</td><td>4.73</td></tr><tr><td>59715</td><td>Bill Watterson</td><td>The Authoritative Calvin and Hobbes: A Calvin and Hobbes Treasury</td><td>4.73</td></tr><tr><td>24815</td><td>Bill Watterson</td><td>The Indispensable Calvin and Hobbes</td><td>4.73</td></tr><tr><td>17927395</td><td>Sarah J. Maas</td><td>A Court of Mist and Fury (A Court of Thorns and Roses, #2)</td><td>4.72</td></tr><tr><td>70487</td><td>Bill Watterson</td><td>Attack of the Deranged Mutant Killer Monster Snow Goons</td><td>4.72</td></tr><tr><td>24816</td><td>Bill Watterson</td><td>Homicidal Psycho Jungle Cat: A Calvin and Hobbes Collection</td><td>4.71</td></tr><tr><td>121792</td><td>Bill Watterson</td><td>The Revenge of the Baby-Sat</td><td>4.71</td></tr><tr><td>2350129</td><td>The Church of Jesus Christ of Latter-day Saints</td><td>Preach My Gospel: A Guide To Missionary Service</td><td>4.71</td></tr><tr><td>24818</td><td>Bill Watterson</td><td>The Days Are Just Packed: A Calvin and Hobbes Collection</td><td>4.68</td></tr><tr><td>265205</td><td>Anonymous, Ronald A. Beers, Ronald A. Beers</td><td>Life Application Study Bible: NIV</td><td>4.67</td></tr><tr><td>9329354</td><td>Brandon Sanderson</td><td>The Way of Kings, Part 1 (The Stormlight Archive #1.1)</td><td>4.67</td></tr><tr><td>99298</td><td>J.K. Rowling, Mary GrandPré</td><td>The Harry Potter Collection 1-4 (Harry Potter, #1-4)</td><td>4.66</td></tr><tr><td>5883777</td><td>Anonymous</td><td>The Holy Bible: English Standard Version</td><td>4.66</td></tr><tr><td>24494</td><td>Bill Watterson</td><td>The Calvin and Hobbes Lazy Sunday Book</td><td>4.66</td></tr><tr><td>43070</td><td>Bill Watterson</td><td>The Essential Calvin and Hobbes: A Calvin and Hobbes Treasury</td><td>4.65</td></tr><tr><td>18337259</td><td>Daniel Abraham, George R.R. Martin, Tommy Patterson</td><td>A Game of Thrones: Comic Book, Issue 1</td><td>4.65</td></tr><tr><td>23753</td><td>Neil Gaiman, Mike Dringenberg, Chris Bachalo, Michael Zulli, Kelly Jones, Charles Vess, Colleen Doran, Malcolm Jones III, Steve Parkhouse, Daniel Vozzo, Lee Loughridge, Steve Oliff, Todd Klein, Dave McKean, Sam Kieth</td><td>The Absolute Sandman, Volume One</td><td>4.65</td></tr><tr><td>7235533</td><td>Brandon Sanderson</td><td>The Way of Kings (The Stormlight Archive, #1)</td><td>4.64</td></tr><tr><td>24813</td><td>Bill Watterson</td><td>The Calvin and Hobbes Tenth Anniversary Book</td><td>4.63</td></tr><tr><td>9814682</td><td>George R.R. Martin</td><td>A Song of Ice and Fire (A Song of Ice and Fire, #1-4)</td><td>4.63</td></tr><tr><td>12177850</td><td>George R.R. Martin</td><td>A Song of Ice and Fire (A Song of Ice and Fire, #1-5)</td><td>4.63</td></tr><tr><td>481749</td><td>James E. Talmage</td><td>Jesus the Christ</td><td>4.63</td></tr><tr><td>46292</td><td>Hafez</td><td>The Divan</td><td>4.63</td></tr><tr><td>6801614</td><td>Eiichirō Oda</td><td>One Piece, Volume 38: Rocketman!! (One Piece, #38 ...

-- %%
-- The Complete Calvin and Hobbes-> IS THE NUMBER ONE BOOK
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.097

-- %% [markdown]
-- Question 2: Write a query to find the least popular book.

-- %%
-- return least popular book
SELECT title, average_rating AS 'Least Popular Book' FROM BooksDB.dbo.books
ORDER BY average_rating DESC;
-- Out:
-- (10000 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:12.918
-- <table><tr><th>title</th><th>Least Popular Book</th></tr><tr><td>The Complete Calvin and Hobbes</td><td>4.82</td></tr><tr><td>Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5)</td><td>4.77</td></tr><tr><td>Words of Radiance (The Stormlight Archive, #2)</td><td>4.77</td></tr><tr><td>ESV Study Bible</td><td>4.76</td></tr><tr><td>Mark of the Lion Trilogy</td><td>4.76</td></tr><tr><td>It's a Magical World: A Calvin and Hobbes Collection</td><td>4.75</td></tr><tr><td>Harry Potter Boxset (Harry Potter, #1-7)</td><td>4.74</td></tr><tr><td>There's Treasure Everywhere: A Calvin and Hobbes Collection</td><td>4.74</td></tr><tr><td>The Authoritative Calvin and Hobbes: A Calvin and Hobbes Treasury</td><td>4.73</td></tr><tr><td>The Indispensable Calvin and Hobbes</td><td>4.73</td></tr><tr><td>Harry Potter Collection (Harry Potter, #1-6)</td><td>4.73</td></tr><tr><td>A Court of Mist and Fury (A Court of Thorns and Roses, #2)</td><td>4.72</td></tr><tr><td>Attack of the Deranged Mutant Killer Monster Snow Goons</td><td>4.72</td></tr><tr><td>Homicidal Psycho Jungle Cat: A Calvin and Hobbes Collection</td><td>4.71</td></tr><tr><td>The Revenge of the Baby-Sat</td><td>4.71</td></tr><tr><td>Preach My Gospel: A Guide To Missionary Service</td><td>4.71</td></tr><tr><td>The Days Are Just Packed: A Calvin and Hobbes Collection</td><td>4.68</td></tr><tr><td>Life Application Study Bible: NIV</td><td>4.67</td></tr><tr><td>The Way of Kings, Part 1 (The Stormlight Archive #1.1)</td><td>4.67</td></tr><tr><td>The Calvin and Hobbes Lazy Sunday Book</td><td>4.66</td></tr><tr><td>The Holy Bible: English Standard Version</td><td>4.66</td></tr><tr><td>The Harry Potter Collection 1-4 (Harry Potter, #1-4)</td><td>4.66</td></tr><tr><td>The Essential Calvin and Hobbes: A Calvin and Hobbes Treasury</td><td>4.65</td></tr><tr><td>A Game of Thrones: Comic Book, Issue 1</td><td>4.65</td></tr><tr><td>The Absolute Sandman, Volume One</td><td>4.65</td></tr><tr><td>The Way of Kings (The Stormlight Archive, #1)</td><td>4.64</td></tr><tr><td>A Song of Ice and Fire (A Song of Ice and Fire, #1-4)</td><td>4.63</td></tr><tr><td>The Calvin and Hobbes Tenth Anniversary Book</td><td>4.63</td></tr><tr><td>A Song of Ice and Fire (A Song of Ice and Fire, #1-5)</td><td>4.63</td></tr><tr><td>The Divan</td><td>4.63</td></tr><tr><td>Jesus the Christ</td><td>4.63</td></tr><tr><td>One Piece, Volume 38: Rocketman!! (One Piece, #38)</td><td>4.63</td></tr><tr><td>The Hate U Give</td><td>4.62</td></tr><tr><td>Crooked Kingdom (Six of Crows, #2)</td><td>4.62</td></tr><tr><td>Harry Potter and the Chamber of Secrets: Sheet Music for Flute with C.D</td><td>4.61</td></tr><tr><td>Vampire Academy Collection (Vampire Academy, #1-3)</td><td>4.61</td></tr><tr><td>Holy Bible: New International Version</td><td>4.61</td></tr><tr><td>Calvin and Hobbes</td><td>4.61</td></tr><tr><td>Harry Potter and the Deathly Hallows (Harry Potter, #7)</td><td>4.61</td></tr><tr><td>Standing for Something: 10 Neglected Virtues That Will Heal Our Hearts and Homes</td><td>4.61</td></tr><tr><td>The Sandman: King of Dreams</td><td>4.61</td></tr><tr><td>Ender's Game, Volume 2: Command School</td><td>4.6</td></tr><tr><td>Queen of Shadows (Throne of Glass, #4)</td><td>4.6</td></tr><tr><td>A Voice in the Wind (Mark of the Lion, #1)</td><td>4.6</td></tr><tr><td>An Echo in the Darkness (Mark of the Lion, #2)</td><td>4.6</td></tr><tr><td>Acheron (Dark-Hunter #14)</td><td>4.59</td></tr><tr><td>The Lord of the Rings: The Art of The Fellowship of the Ring</td><td>4.59</td></tr><tr><td>The Kindly Ones (The Sandman #9)</td><td>4.59</td></tr><tr><td>The Lord of the Rings: The Return of the King: Visual Companion</td><td>4.59</td></tr><tr><td>Clockwork Princess (The Infernal Devices, #3)</td><td>4.59</td></tr><tr><td>J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings</td><td>4.59</td></tr><tr><td>The Mortal Instruments (The Mortal Instruments #1-4)</td><td>4.59</td></tr><tr><td>BookRags Summary:  A Storm of Swords</td><td>4. ...

-- %% [markdown]
-- \-- Twilight (Twilight, #1) IS-\> THE LEAST POPULAR BOOK

-- %% [markdown]
-- Question 3: Which tag is the most popular?

-- %%
-- return most popular tag
SELECT TOP 1 tag_id, count FROM BooksDB.dbo.books ORDER BY count DESC;
-- Out:
-- : Msg 207, Level 16, State 1, Line 2
-- Invalid column name 'tag_id'.
-- : Msg 207, Level 16, State 1, Line 2
-- Invalid column name 'count'.
-- Total execution time: 00:00:00.044

-- %% [markdown]
-- \-- The Complete Calvin and Hobbes-\> IS THE MOST POPULAR TAG

-- %% [markdown]
-- Question 4: What is the name of the most popular tag?

-- %%
-- return name of most popular tag
SELECT TOP 1 title, average_rating AS 'Best Book' FROM BooksDB.dbo.books
GROUP BY MAX(average_rating);
-- Out:
-- : Msg 144, Level 15, State 1, Line 3
-- Cannot use an aggregate or a subquery in an expression used for the group by list of a GROUP BY clause.
-- Total execution time: 00:00:00.043

-- %% [markdown]
-- Question 5: How many books where released in the first decade of 2000?

-- %%
SELECT COUNT(*)

-- %%
-- return number of books published in the first decade of 2000
SELECT COUNT(title) AS 'Books Published from 2000 to 2010' FROM BooksDB.dbo.books
WHERE original_publication_year BETWEEN 2000 AND 2010;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.082
-- <table><tr><th>Books Published from 2000 to 2010</th></tr><tr><td>3594</td></tr></table>

-- %% [markdown]
-- Question 6: How many book titles contain the word Happy?

-- %%
-- return number of books that contain the word Happy
SELECT COUNT(title) FROM BooksDB.dbo.books WHERE title LIKE '%Happy%';
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.101
-- <table><tr><th>(No column name)</th></tr><tr><td>13</td></tr></table>

-- %% [markdown]
-- Question 7: List the books from the top 3 authors from question 1.  If there is more than one author just use the first one. Sort the titles <span style="background-color: rgba(127, 127, 127, 0.1); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">alphabetically by author and then by average_rating, best rated to lowest. Does order matter in sorting?</span>

-- %%
SELECT TOP 3 authors, average_rating FROM BooksDB.dbo.books ORDER BY average_rating DESC;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.097
-- <table><tr><th>authors</th><th>average_rating</th></tr><tr><td>Bill Watterson</td><td>4.82</td></tr><tr><td>Brandon Sanderson</td><td>4.77</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>4.77</td></tr></table>

-- %%
-- return all books from the top 3 authors, sort by author and rating
SELECT authors, title, average_rating AS 'Rating' FROM BooksDB.dbo.books
WHERE authors IN (SELECT TOP 3 authors FROM BooksDB.dbo.books
ORDER BY average_rating DESC)
-- Out:
-- (41 rows affected)
-- Total execution time: 00:00:00.169
-- <table><tr><th>authors</th><th>title</th><th>Rating</th></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Sorcerer's Stone (Harry Potter, #1)</td><td>4.44</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Order of the Phoenix (Harry Potter, #5)</td><td>4.46</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Chamber of Secrets (Harry Potter, #2)</td><td>4.37</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Goblet of Fire (Harry Potter, #4)</td><td>4.53</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Deathly Hallows (Harry Potter, #7)</td><td>4.61</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Half-Blood Prince (Harry Potter, #6)</td><td>4.54</td></tr><tr><td>Brandon Sanderson</td><td>The Final Empire (Mistborn, #1)</td><td>4.43</td></tr><tr><td>Brandon Sanderson</td><td>The Way of Kings (The Stormlight Archive, #1)</td><td>4.64</td></tr><tr><td>Brandon Sanderson</td><td>The Well of Ascension (Mistborn, #2)</td><td>4.35</td></tr><tr><td>Brandon Sanderson</td><td>The Hero of Ages (Mistborn, #3)</td><td>4.46</td></tr><tr><td>Brandon Sanderson</td><td>Words of Radiance (The Stormlight Archive, #2)</td><td>4.77</td></tr><tr><td>Brandon Sanderson</td><td>Steelheart (The Reckoners, #1)</td><td>4.16</td></tr><tr><td>Bill Watterson</td><td>The Essential Calvin and Hobbes: A Calvin and Hobbes Treasury</td><td>4.65</td></tr><tr><td>Brandon Sanderson</td><td>Elantris (Elantris, #1)</td><td>4.17</td></tr><tr><td>Brandon Sanderson</td><td>The Alloy of Law (Mistborn, #4)</td><td>4.2</td></tr><tr><td>Brandon Sanderson</td><td>Warbreaker (Warbreaker, #1)</td><td>4.22</td></tr><tr><td>Bill Watterson</td><td>The Calvin and Hobbes Tenth Anniversary Book</td><td>4.63</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>The Harry Potter Collection 1-4 (Harry Potter, #1-4)</td><td>4.66</td></tr><tr><td>Brandon Sanderson</td><td>Firefight (The Reckoners, #2)</td><td>4.29</td></tr><tr><td>Brandon Sanderson</td><td>Shadows of Self (Mistborn, #5)</td><td>4.3</td></tr><tr><td>Brandon Sanderson</td><td>Mistborn Trilogy Boxed Set (Mistborn, #1-3)</td><td>4.55</td></tr><tr><td>Brandon Sanderson</td><td>The Emperor's Soul</td><td>4.33</td></tr><tr><td>Brandon Sanderson</td><td>The Rithmatist (The Rithmatist, #1)</td><td>4.25</td></tr><tr><td>Brandon Sanderson</td><td>Calamity (The Reckoners, #3)</td><td>4.2</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5)</td><td>4.77</td></tr><tr><td>Brandon Sanderson</td><td>The Bands of Mourning (Mistborn, #6)</td><td>4.45</td></tr><tr><td>Bill Watterson</td><td>The Complete Calvin and Hobbes</td><td>4.82</td></tr><tr><td>Bill Watterson</td><td>It's a Magical World: A Calvin and Hobbes Collection</td><td>4.75</td></tr><tr><td>Brandon Sanderson</td><td>Legion (Legion, #1)</td><td>4.13</td></tr><tr><td>Brandon Sanderson</td><td>Mitosis (The Reckoners, #1.5)</td><td>3.87</td></tr><tr><td>Bill Watterson</td><td>The Days Are Just Packed: A Calvin and Hobbes Collection</td><td>4.68</td></tr><tr><td>Bill Watterson</td><td>The Calvin and Hobbes Lazy Sunday Book</td><td>4.66</td></tr><tr><td>Bill Watterson</td><td>There's Treasure Everywhere: A Calvin and Hobbes Collection</td><td>4.74</td></tr><tr><td>Bill Watterson</td><td>The Authoritative Calvin and Hobbes: A Calvin and Hobbes Treasury</td><td>4.73</td></tr><tr><td>Bill Watterson</td><td>The Indispensable Calvin and Hobbes</td><td>4.73</td></tr><tr><td>Bill Watterson</td><td>Homicidal Psycho Jungle Cat: A Calvin and Hobbes Collection</td><td>4.71</td></tr><tr><td>Brandon Sanderson</td><td>Secret History (Mistborn, #3.5)</td><td>4.38</td></tr><tr><td>Brandon Sanderson</td><td>Alcatraz Versus the Evil Librarians (Alcatraz, #1)</td><td>3.87</td></tr><tr><td>Bill Watterson</td><td>The Revenge of the Baby-Sat</td><td>4.71</td></tr><tr><td>Brandon Sanderson</td><td>The Way of Kings,  ...

-- %% [markdown]
-- Question 8: Take a close look at J.K. Rowling.  Is her top rated book on this list from question 1?  Why might this be? How could we account for this?

-- %% [markdown]
-- Try updating your above query to include all of J.K. Rowling's books.
--
-- Are there any other issues?
--
-- > Her book has another author in it.  Wld have to make another search.

-- %%
-- Try updating your above query to include all of J.K. Rowling's books

-- %% [markdown]
-- Question 9: Write a query that returns the number of Authors whose first name is between rock and roll.

-- %%
-- return number of authors whose first name is between rock and roll

SELECT DISTINCT (authors) AS 'Rock and Roll Writers'
FROM BooksDB.dbo.books
where authors BETWEEN 'rock' and 'roll';
-- Out:
-- (16 rows affected)
-- Total execution time: 00:00:00.296
-- <table><tr><th>Rock and Roll Writers</th></tr><tr><td>Rod Campbell</td></tr><tr><td>Roddy Doyle</td></tr><tr><td>Roderick Gordon, Brian  Williams</td></tr><tr><td>Rodman Philbrick</td></tr><tr><td>Roger Fisher, William Ury, Bruce Patton</td></tr><tr><td>Roger Lea MacBride, David Gilleece</td></tr><tr><td>Roger Lowenstein</td></tr><tr><td>Roger Zelazny</td></tr><tr><td>Roger Zelazny, Sönmez Güven</td></tr><tr><td>Rohinton Mistry</td></tr><tr><td>Roland Barthes, Annette Lavers</td></tr><tr><td>Roland Barthes, Richard Howard</td></tr><tr><td>Roland Merullo</td></tr><tr><td>Roland Smith</td></tr><tr><td>Rolf Dobelli</td></tr><tr><td>Rolf Potts</td></tr></table>

-- %% [markdown]
-- ## Part 2. Write your own question and write a query to answer it.
--
-- Your Question:  Click here to add

-- %%
-- What is the longest title?
SELECT TOP 1 title AS 'Longest Title'FROM BooksDB.dbo.books
ORDER BY len(title) DESC;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.055
-- <table><tr><th>Longest Title</th></tr><tr><td>Soccernomics: Why England Loses, Why Germany and Brazil Win, and Why the U.S., Japan, Australia, Turkey--and Even Iraq--Are Destined to Become the Kings of the World's Most Popular Sport</td></tr></table>

-- %% [markdown]
-- Your Question: Click here to add

-- %%
-- which author has written the most books?
SELECT authors, FROM BooksDB.dbo.books
ORDER BY authors DESC;
-- Out:
-- : Msg 156, Level 15, State 1, Line 2
-- Incorrect syntax near the keyword 'FROM'.
-- Total execution time: 00:00:00.046

-- %% [markdown]
-- **Some Question Examples:**
--
-- Write a query that returns the longest title?
--
-- Which Author has written the most books?
--
-- Top  ten books written the year I was born?
